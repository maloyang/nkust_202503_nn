# %% [markdown]
# # Demo: 公共腳踏車應用

# %% [markdown]
# ## 新竹市公共自行車租賃系統(YouBike): https://data.gov.tw/dataset/67781

# %%
import requests

# 使用政府公開網的資料
#url = "https://odws.hccg.gov.tw/001/Upload/25/OpenData/9059/59/8544b041-b6ab-4b49-bab5-e10237d5c88f.csv"
url = 'https://raw.githubusercontent.com/maloyang/csu_202302_ML/main/W03/bike_01_%E6%96%B0%E7%AB%B9%E5%B8%82.csv' #避免被檔，使用以下載好的csv檔

r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %% [markdown]
# - 對取回來的資料進行編碼
# - 並用csv套件解析它

# %%
import csv
decoded_content = r.content.decode('utf-8')
#print(decoded_content)

cr = csv.reader(decoded_content.splitlines(), delimiter=',')
data_list = list(cr)
# 輸出前3項
print(data_list[0:3])
# Out:
# [['\ufeff站點名稱', '經度', '緯度', '圖片URL', '站點位置', 'F6', 'F7'], ['新竹火車站(前站)', '120.971459', '24.801815', 'http://opendata-manage.hccg.gov.tw/img/24/youbike01.jpg', '中華路二段445號(火車站前廣場)', '', ''], ['東門圓環', '120.970556', '24.803866', 'http://opendata-manage.hccg.gov.tw/img/24/youbike02.jpg', '勝利路2號(對面圓環人行道)', '', '']]

# %% [markdown]
# ## 直接下載檔案解析 (如果使用colab下載csv解析失敗時，使用這邊的程式)
# - 下載的檔案已存成 【bike_01_新竹市.csv】，並放在同一資料夾中
# - 下載的檔案連結為[link](https://odws.hccg.gov.tw/001/Upload/25/OpenData/9059/59/8544b041-b6ab-4b49-bab5-e10237d5c88f.csv)
#
# - 程式：
#
# ```python
# #使用colab讀csv檔前，需要先使用這行來上傳檔案
# from google.colab import files
# uploaded = files.upload()
#
# ```
#
# ```python
# import csv
#
# fn = 'bike_01_新竹市.csv'
# with open(fn, 'r', encoding='utf8') as csvfile:
#     rows = csv.reader(csvfile)
#     data_list = list(rows)
# ```

# %% [markdown]
# - 了解 list 的操作

# %%
data_list[0]
# Out:
# ['\ufeff站點名稱', '經度', '緯度', '圖片URL', '站點位置', 'F6', 'F7']

# %%
data_list[1]
# Out:
# ['新竹火車站(前站)',
#  '120.971459',
#  '24.801815',
#  'http://opendata-manage.hccg.gov.tw/img/24/youbike01.jpg',
#  '中華路二段445號(火車站前廣場)',
#  '',
#  '']

# %%
data_list[1:3]
# Out:
# [['新竹火車站(前站)',
#   '120.971459',
#   '24.801815',
#   'http://opendata-manage.hccg.gov.tw/img/24/youbike01.jpg',
#   '中華路二段445號(火車站前廣場)',
#   '',
#   ''],
#  ['東門圓環',
#   '120.970556',
#   '24.803866',
#   'http://opendata-manage.hccg.gov.tw/img/24/youbike02.jpg',
#   '勝利路2號(對面圓環人行道)',
#   '',
#   '']]

# %% [markdown]
# ### 我們改用geopy這一個函式庫:

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)

# %%
import folium
from geopy.geocoders import Nominatim

def get_gps_coordinates(location_name):
    """
    取得指定地名的 GPS 座標。

    Args:
        location_name (str): 地名。

    Returns:
        tuple: (緯度, 經度)，如果找不到則返回 None。
    """
    try:
        geolocator = Nominatim(user_agent="my_geocoder")
        location = geolocator.geocode(location_name)
        if location:
            return location.latitude, location.longitude
        else:
            return None
    except Exception as e:
        print(f"發生錯誤：{e}")
        return None

# %%
location = get_gps_coordinates("新竹市")
print(location)

m = folium.Map(location=location, zoom_start=15)

for item in data_list[1:]:
    try:
        # item[2]=緯度, item[1]=經度, item[0]=名稱
        folium.Marker([float(item[2]), float(item[1])], popup=item[0]).add_to(m)
    except Exception as e:
        print(e.args)
# Out:
# (24.8066333, 120.9686833)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6098f39d12278593f464eba2c015061e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6098f39d12278593f464eba2c015061e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6098f39d12278593f464eba2c015061e = L.map(
#                 &quot;map_6098f39d12278593f464eba2c015061e&quot;,
#                 {
#                     center: [24.8066333, 120.9686833],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d937c7984c72453b79ca9f5ead3caa3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d937c7984c72453b79ca9f5ead3caa3.addTo(map_6098f39d12278593f464eba2c015061e);
#
#
#             var marker_e44b7877529a2a7cb7923007228e5ae6 = L.marker(
#                 [24.801815, 120.971459],
#                 {
# }
#             ).addTo(map_6098f39d12278593f464eba2c015061e);
#
#
#         var popup_62cd0ec0e12e7d40c326eec4d98842ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a23038606b626f7d1d3001fc0733cdf = $(`&lt;div id=&quot;html_0a23038606b626f7d1d3001fc0733cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新竹火車站(前站)&lt;/div&gt;`)[0];
#                 popup_62cd0ec0e12e7d40c326eec4d98842ab.setContent(html_0a23038606b626f7d1d3001fc0733cdf);
#
#
#
#         marker_e44b7877529a2a7cb7923007228e5ae6.bindPopup(popup_62cd0ec0e12e7d40c326eec4d98842ab)
#         ;
#
#
#
#
#             var marker_496ac057c95fb964cae9fa1cc6f06bcf = L.marker(
#                 [24.803866, 120.970556],
#                 {
# }
#             ).addTo(map_6098f39d12278593f464eba2c015061e);
#
#
#         var popup_e76a39fb0d5e0d093cd06d3103a39e1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93d6c36c8facaa070107e90302d163c = $(`&lt;div id=&quot;html_f93d6c36c8facaa070107e90302d163c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東門圓環&lt;/div&gt;`)[0];
#                 popup_e76a39fb0d5e0d093cd06d3103a39e1c.setContent(html_f93d6c36c8facaa070107e90302d163c);
#
#
#
#         marker_496ac057c95fb964cae9fa1cc6f06bcf.bindPopup(popup_e76a39fb0d5e0d093cd06d3103a39e1c)
#         ;
#
#
#
#
#             var marker_611c85cf8518e896451361ff18130272 = L.marker(
#                 [24.806138, 120.96926],
#                 {
# }
#             ).addTo(map_6098f39d12278593f464eba2c015061e);
#
#
#         var popup_80f1869d4a8477a7253f17558b1429dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eeabcbf74d509616e468d856c26f4dac = $(`&lt;div id=&quot;html_eeabcbf74d509616e468d856c26f4dac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新竹市政府&lt;/div&gt;`)[0];
#                 popup_80f1869d4a8477a7253f17558b1429dd.setContent(html_eeabcbf74d509616e468d856c26f4dac);
#
#
#
#         marker_611c85cf8518e896451361ff18130272.bindPopup(popup_80f1869d4a8477a7253f17558b1429dd)
#         ;
#
#
#
#
#             var marker_38e908af4cf8369d785ba998ce1b997e = L.marker(
#                 [24.80167, 120.96576],
#                 {
# }
#             ).addTo(map_6098f39d12278593f464eba2c015061e);
#
#
#         var popup_960347429dd3dd4e00b3473c5fd17b1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_510f94d91475573a1f167dc42661b704 = $(`&lt;div id=&quot;html_510f94d91475573a1f167dc42661b704&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;明志書院立體停車場&lt;/div&gt;`)[0];
#                 popup_960347429dd3dd4e00b3473c5fd17b1f.setContent(html_510f94d91475573a1f167dc42661b704);
#
#
#
#         marker_38e908af4cf8369d785ba998ce1b997e.bindPopup(popup_960347429dd3dd4e00b3473c5fd17b1f)
#         ;
#
#
#
#
#             var marker_db1943fce440f62dc92e15edde80c5e9 = L.marker(
#                 [24.804317, 120.973662],
#                 {
# }
#             ).addTo(map_6098f39d12278593f464eba2c015061e);
#
#
#         var popup_32650c5ac672c39d2480a9daa88ca274 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7c8c4f3a1f39c43b7ec685f540a08d8 = $(`&lt;div id=&quot;html_a7c8c4f3a1f39c43b7ec685f540a08d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;辛志平校長故居&lt;/div&gt;`)[0];
#                 popup_32650c5ac672c39d2480a9daa88ca274.setContent(html_a7c8c4f3a1f39c43b7ec685f540a08d8);
#
#
#
#         marker_db1943fce440f62dc92e15edde80c5e9.bindPopup(popup_32650c5ac672c39d2480a9daa88ca274)
#         ;
#
#
#
#
#             var marker_af7b05fa39592aa860cb07cb7ad8f670 = L.marker(
#                 [24.808979, 120.967098],
#                 {
# }
#             ).addTo(

# %% [markdown]
# - 下載你的成果

# %%
m.save('demo01.html')

# %% [markdown]
# - 如果使用colab，可以這樣下載成果

# %%
from google.colab import files
files.download('demo01.html')

# %% [markdown]
# - 練習題: 把地址訊息加入地圖中

# %%
# TODO: 填入你的程式

# %% [markdown]
# - 練習題: 改成使用tooltip顯示訊息
